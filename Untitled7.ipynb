# %%
import pandas as pd
import numpy as np
import gensim

# %%
# Load the pre-trained word2vec model
model_path = 'GoogleNews-vectors-negative300.bin'
model = gensim.models.KeyedVectors.load_word2vec_format(model_path, binary=True)

# %%
# Define the list of words for bed sizes
# bed_size_key_words = ['Twin',  
#     'Queen', 
#     'King' ,
#     'California King',
#     'Twin XL' ,
#     'Full' ,
#     'Single' ,
#     'Sofa' ,
#     'Rollaway' ,
#     'Bunk' ,
#     'Murphy' ,
#     'Trundle' ,
#     'Daybed',
#     'Crib' , 'Pack' 
#     ,'Air Mattress', 
#     'Twin Beds', 
#     'Double Bed', 
#     'Queen Beds',
#     'Double Bed', 
#     'Queen Bed',                  
#     'King Beds' ,
#     'California King Beds',
#     'Twin XL Beds' ,
#     'Full Beds' ,
#     'Single Beds' ,
#     'Sofa Beds' ,
#     'Rollaway Beds' ,
#     'Bunk Beds' ,
#     'Murphy Beds' ,
#     'Trundle Beds' ,
#     'Daybed Beds',
#         'Crib Beds' , 'Pack Beds'                  
#  ]



# room_style_key_words = [
#     'Queen',
#     'Apartment',
#     'Standard',
#     'Suite',
#     'Deluxe',
#     'Double',
#     'Executive',
#     'Leisure',
#     'Club',
#     'Superior',
#     'Connecting',
#     'Accessible',
#     'Family',
#     'Pet-Friendly',
#     'Jacuzzi',
#     'Adjoining',
#     'Loft',
#     'Penthouse Suite',
#     'Standard Room',
#     'Suite Room',
#     'Deluxe Room',
#     'Executive Room',
#     'Club Room',
#     'Superior Room',
#     'Connecting Room',
#     'Accessible Room',
#     'Family Room',
#     'Pet-Friendly Room',
#     'Jacuzzi Room',
#     'Adjoining Room',
#     'Loft Room',
#     'Penthouse Suite Room'
    
# ]

# %%
bed_size_key_words = [ 
    'Queen', 
    'King' ,
    'California King',
    'Twin XL' ,
    'Full' ,
    'Single' ,
    'Twin', 
    'Sofa' ,
    'Rollaway' ,
    'Bunk' ,
    'Murphy' ,
    'Trundle' ,
    #'Premium',
    'Daybed',
    'Queens',
    'Crib' , 'Pack' 
    ,'Air Mattress', 
    'Twin Beds'

 ]



room_style_key_words = [
    'Standard',
    'Deluxe',
    'Joint',
    'Superior',
    'Studio',
    'Premium',
    'Dormitory',
    'Economy',
    'Connecting',
    'Junior Suite ',
    'Suite Club',
    'Suite Premium',
    'Suite Presidential',
    'Studio Standard',
    'Studio Delux',
    'Studio Suite',
    'Studio Superior',
    'Suite'
    'Apartment',
    'Premier',
    'Executive',
    'Cabana',
    'Club',
    'Villa',
    'Penthouse',
    'Leisure'
]

# %%
df = pd.read_csv("merged.csv")
# Out:
# /tmp/ipykernel_8541/1330870347.py:1: DtypeWarning: Columns (4,7,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("merged.csv")

# %%
# df = pd.read_csv("merged.csv")
# df = df.head(100)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   search_dt              1048575 non-null  object
#  1   checkin_date           1048575 non-null  object
#  2   Check-out Date         1048575 non-null  object
#  3   property_name          1048575 non-null  object
#  4   Star Rating(out of 5)  883587 non-null   object
#  5   room_type              1048258 non-null  object
#  6   room_rate              1029822 non-null  object
#  7   Review Score           937870 non-null   object
#  8   location_desc          1048575 non-null  object
#  9   Distance               1048575 non-null  object
#  10  Room Details           1043447 non-null  object
#  11  Breakfast              197022 non-null   object
#  12  Cancelations           491596 non-null   object
#  13  Availability           472387 non-null   object
#  14  Unnamed: 14            214 non-null      object
#  15  Unnamed: 15            132 non-null      object
# dtypes: object(16)
# memory usage: 128.0+ MB

# %%
#df['room_type'] = df['HotelBeds RoomName']

# %%
replacements = {"Two": "2", "Three": "3", "1":" 1 ", "2":" 2 ", "3":" 3 ", "-":" " ,"/":" / " }

# replace values in the 'room_type' column using the dictionary
df['room_type'] = df['room_type'].replace(replacements, regex=True)

# %%
df['room_type'] = df['room_type'].str.title()

# %%
df.head(4)
# Out:
#              search_dt checkin_date Check-out Date  \
# 0  02-16-2023 18:00:15   2023-02-16     2023-02-17
# 1  02-16-2023 18:00:15   2023-02-16     2023-02-17
# 2  02-16-2023 18:00:15   2023-02-16     2023-02-17
# 3  02-16-2023 18:00:15   2023-02-16     2023-02-17
#
#                                        property_name Star Rating(out of 5)  \
# 0  Red Roof Inn PLUS+ San Antonio Downtown - Rive...                   3.0
# 1                 Clarion Pointe near Medical Center                   2.0
# 2       Comfort Suites Medical Center Near Six Flags                   3.0
# 3           Comfort Inn & Suites San Antonio Airport                   3.0
#
#                                            room_type room_rate Review Score  \
# 0  Superior King Room Disability Access Roll In S...       NaN          6.7
# 1               King Room   Accessible / Non Smoking     US$59          7.2
# 2              King Suite   Accessible / Non Smoking     US$76          7.8
# 3  King Room   Mobility And Hearing Accessible / ...     US$79          7.4
#
#                           location_desc                              Distance  \
# 0     Downtown - Riverwalk, San Antonio     Downtown - Riverwalk, San Antonio
# 1    Northwest San Antonio, San Antonio    Northwest San Antonio, San Antonio
# 2    Northwest San Antonio, San Antonio    Northwest San Antonio, San Antonio
# 3  North San Antonio - SAT, San Antonio  North San Antonio - SAT, San Antonio
#
#                                         Room Details Breakfast  \
# 0                           1 extra-large double bed       NaN
# 1                           1 extra-large double bed       yes
# 2  Private suite2 beds (1 extra-large double, 1 s...       yes
# 3                           1 extra-large double bed       yes
#
#                                Cancelations  \
# 0                                       NaN
# 1  FREE cancellation | No prepayment needed
# 2                                       NaN
# 3                                       NaN
#
#                             Availability Unnamed: 14 Unnamed: 15
# 0                                    NaN         NaN         NaN
# 1                                    NaN         NaN         NaN
# 2  Only 6 left at this price on our site         NaN         NaN
# 3                                    NaN         NaN         NaN

# %%
# Define a function to tokenize the room types and extract bigrams and trigrams
def get_ngrams(room_type):
    tokens = room_type.split()
    bigrams = [' '.join(tokens[i:i+2]) for i in range(len(tokens)-1)]
    trigrams = [' '.join(tokens[i:i+3]) for i in range(len(tokens)-2)]
    return tokens + bigrams + trigrams

df['room_type'] = df['room_type'].astype(str)
# Apply the get_ngrams function to the room types column
df['ngrams'] = df['room_type'].apply(get_ngrams)

# %%
df['ngrams'][0]
# Out:
# ['Superior',
#  'King',
#  'Room',
#  'Disability',
#  'Access',
#  'Roll',
#  'In',
#  'Shower',
#  'Smoke',
#  'Free',
#  'Superior King',
#  'King Room',
#  'Room Disability',
#  'Disability Access',
#  'Access Roll',
#  'Roll In',
#  'In Shower',
#  'Shower Smoke',
#  'Smoke Free',
#  'Superior King Room',
#  'King Room Disability',
#  'Room Disability Access',
#  'Disability Access Roll',
#  'Access Roll In',
#  'Roll In Shower',
#  'In Shower Smoke',
#  'Shower Smoke Free']

# %%
import spacy

nlp = spacy.load("en_core_web_sm")


def get_bed_count(trigrams):
    for trigram in trigrams:
        if "Bed" in trigram or "Beds" in trigram or "bed" in trigram or "beds" in trigram:
            doc = nlp(trigram)
            for token in doc:
                if token.is_digit:
                    return int(token.text)
    return 1

df["bed_count"] = df["ngrams"].apply(get_bed_count)
# Out:
# 2023-05-11 09:14:15.849509: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-11 09:14:32.608810: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-05-11 09:14:32.609199: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-05-11 09:14:32.609224: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-05-11 09:14:38.738640: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-05-11 09:14:38.746181: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-11 09:14:38.746239: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ushan-Inspiron-5558): /proc/driver/nvidia/version does not exist

# %%
df['room_type_1'] = df['room_type']

# %%
df.tail(2)
# Out:
#                    search_dt checkin_date Check-out Date  \
# 1048573  02-15-2023 20:03:25   2023-02-17     2023-02-18
# 1048574  02-15-2023 20:03:25   2023-02-17     2023-02-18
#
#                                 property_name Star Rating(out of 5)  \
# 1048573        Washington Marriott Georgetown                     4
# 1048574  Coda on Half, a Placemakr Experience                     4
#
#                      room_type room_rate Review Score          location_desc  \
# 1048573   Guest Room,  1  King    US$269          7.8  Northwest, Washington
# 1048574  One Bedroom Apartment    US$218          9.1  Southeast, Washington
#
#                       Distance  \
# 1048573  Northwest, Washington
# 1048574  Southeast, Washington
#
#                                               Room Details Breakfast  \
# 1048573                           1 extra-large double bed       NaN
# 1048574  Entire apartment | 1 bedroom | 1 living room |...       NaN
#
#                                      Cancelations  \
# 1048573  FREE cancellation | No prepayment needed
# 1048574                                       NaN
#
#                                         Availability Unnamed: 14 Unnamed: 15  \
# 1048573  Only 5 rooms left at this price on our site         NaN         NaN
# 1048574        Only 1 left at this price on our site         NaN         NaN
#
#                                                     ngrams  bed_count  \
# 1048573  [Guest, Room,, 1, King, Guest Room,, Room, 1, ...          1
# 1048574  [One, Bedroom, Apartment, One Bedroom, Bedroom...          1
#
#                    room_type_1
# 1048573   Guest Room,  1  King
# 1048574  One Bedroom Apartment

# %%
import re

# loop through the rows of the dataframe
for index, row in df.iterrows():
    room_type = row['room_type']
    
    # extract the room style and bed size
    room_style = ''
    bed_size = ''
    
    if 'Double' in room_type:
        room_style = 'Double'
        bed_size = room_type.replace('Double', '').strip()
    elif 'Triple' in room_type:
        room_style = 'Triple'
        bed_size = room_type.replace('Triple', '').strip()
    elif 'Quadruple' in room_type:
        room_style = 'Quadruple'
        bed_size = room_type.replace('Quadruple', '').strip()
    else:
        room_style = ''
        bed_size = room_type
        
    
    # update the row with the new information
    df.at[index, 'room_style_1'] = room_style
    df.at[index, 'room_type_1'] = bed_size

# %%
df['ngrams'][0]

# %%
bed_size_key_words
# Out:
# ['Queen',
#  'King',
#  'California King',
#  'Twin XL',
#  'Full',
#  'Single',
#  'Twin',
#  'Sofa',
#  'Rollaway',
#  'Bunk',
#  'Murphy',
#  'Trundle',
#  'Daybed',
#  'Queens',
#  'Crib',
#  'Pack',
#  'Air Mattress',
#  'Twin Beds']

# %%
import pandas as pd
import re

# Define a regular expression to match trigrams that end with "bed" or "beds"
regex = re.compile(r'\b\w+\s+\w+\s+(beds?|sofa bed)\b')

# Define a function to find the best matching bed size keyword for a given ngram
def get_best_match(ngram):
    matches = []
    for bed_size in bed_size_key_words:
        if bed_size in ngram:
            matches.append(bed_size)
    if len(matches) == 0:
        return None
    elif len(matches) == 1:
        return matches[0]
    else:
        # If there are multiple matches, return the longest match
        return max(matches, key=len)

# Find the best matching bed size keyword for each ngram and add it to a new column
df['bed_size'] = df['ngrams'].apply(lambda x: get_best_match(x))

# %%
df.head(100)
# Out:
#     Vervotech ID  SupplierHotelId SupplierName      GroupId  \
# 0       15111741           782331    HotelBeds   15111741-1
# 1       15111788           782334    HotelBeds   15111788-1
# 2       15131097           782325    HotelBeds   15131097-1
# 3       15294880           766775    HotelBeds   15294880-1
# 4       15294880           766775    HotelBeds   15294880-2
# ..           ...              ...          ...          ...
# 95      15780037           145605    HotelBeds   15780037-9
# 96      15780037           145605    HotelBeds  15780037-10
# 97      15780037           145605    HotelBeds  15780037-11
# 98      15780037           145605    HotelBeds  15780037-12
# 99      15780037           145605    HotelBeds  15780037-12
#
#    HotelBeds RoomCode          HotelBeds RoomName  \
# 0           APT.KG-PE  APARTMENT PREMIER KING BED
# 1              APT.2K       APARTMENT 2 KING BEDS
# 2              APT.KG     APARTMENT KING SIZE BED
# 3              DBL.QN       DOUBLE QUEEN SIZE BED
# 4            SUI.KG-1         SUITE KING SIZE BED
# ..                ...                         ...
# 95             DBL.EY              DOUBLE ECONOMY
# 96             DBL.KG        DOUBLE KING SIZE BED
# 97             SUI.LO                  SUITE LOFT
# 98             ROO.PE                Room PREMIER
# 99           DBL.PE-5              DOUBLE PREMIER
#
#    Vervotech MappedStandardName               room_type  \
# 0             Apartment Premier  Apartment Premier  Bed
# 1                     Apartment     Apartment  2   Beds
# 2                     Apartment     Apartment  Size Bed
# 3                    Queen Room        Double  Size Bed
# 4                         Suite         Suite  Size Bed
# ..                          ...                     ...
# 95                      Economy          Double Economy
# 96                    King Room        Double  Size Bed
# 97                   Loft Suite              Suite Loft
# 98                      Premier            Room Premier
# 99                      Premier          Double Premier
#
#                                                ngrams  bed_count  \
# 0   [Apartment, Premier, King, Bed, Apartment Prem...          1
# 1   [Apartment, 2, King, Beds, Apartment 2, 2 King...          2
# 2   [Apartment, King, Size, Bed, Apartment King, K...          1
# 3   [Double, Queen, Size, Bed, Double Queen, Queen...          1
# 4   [Suite, King, Size, Bed, Suite King, King Size...          1
# ..                                                ...        ...
# 95                  [Double, Economy, Double Economy]          1
# 96  [Double, King, Size, Bed, Double King, King Si...          1
# 97                          [Suite, Loft, Suite Loft]          1
# 98                      [Room, Premier, Room Premier]          1
# 99                  [Double, Premier, Double Premier]          1
#
#                room_type_1 room_style_1 bed_size room_style  no_of_person  \
# 0   Apartment Premier  Bed                  King    Premier           NaN
# 1      Apartment  2   Beds                  King                      NaN
# 2      Apartment  Size Bed                  King                      NaN
# 3                 Size Bed       Double    Queen     Double           2.0
# 4          Suite  Size Bed                  King                      NaN
# ..                     ...          ...      ...        ...           ...
# 95                 Economy       Double     None    Economy           2.0
# 96                Size Bed       Double     King     Double           2.0
# 97              Suite Loft                  None                      NaN
# 98            Room Premier                  None    Premier           NaN
# 99                 Premier       Double     None    Premier           2.0
#
#     no_of_people
# 0            2.0
# 1            4.0
# 2            2.0
# 3            2.0
# 4            2.0
# ..           ...
# 95           2.0
# 96           2.0
# 97           1.0
# 98           2.0
# 99           2.0
#
# [100 rows x 16 columns]

# %%
num_null = df['bed_size'].isnull().sum()
num_null
# Out:
# 1037

# %%
# Loop through each row of the DataFrame
for index, row in df.iterrows():
    bed_size = row['bed_size']
    room_type = row['room_type']
    
    # Check if the bed_size is not None
    if bed_size is not None:
        # Remove the bed_size keyword from the room_type string
        room_type = room_type.replace(bed_size, '').strip()
        room_type = room_type.replace('beds', '').strip()
        
        # Update the room_type column in the DataFrame
        df.at[index, 'room_type'] = room_type

# %%
df.head(2)
# Out:
#    Vervotech ID  SupplierHotelId SupplierName     GroupId HotelBeds RoomCode  \
# 0      15111741           782331    HotelBeds  15111741-1          APT.KG-PE
# 1      15111788           782334    HotelBeds  15111788-1             APT.2K
#
#            HotelBeds RoomName Vervotech MappedStandardName  \
# 0  APARTMENT PREMIER KING BED            Apartment Premier
# 1       APARTMENT 2 KING BEDS                    Apartment
#
#                 room_type                                             ngrams  \
# 0  Apartment Premier  Bed  [Apartment, Premier, King, Bed, Apartment Prem...
# 1     Apartment  2   Beds  [Apartment, 2, King, Beds, Apartment 2, 2 King...
#
#    bed_count             room_type_1 room_style_1 bed_size room_style  \
# 0          1  Apartment Premier  Bed                  King    Premier
# 1          2     Apartment  2   Beds                  King
#
#    no_of_person  no_of_people
# 0           NaN           2.0
# 1           NaN           4.0

# %%
# Define a function to find the best matching key word for a list of ngrams
def get_best_match(ngrams, key_words):
    best_match = ''
    best_similarity = -1
    for ngram in ngrams:
        if ngram in model:
            for key_word in key_words:
                # Split key word into individual words
                key_word_tokens = key_word.split()
                # Check if all words in key word are present in ngram
                if all(token in ngram.split() for token in key_word_tokens):
                    similarity = model.similarity(ngram, key_word)
                    if similarity > best_similarity:
                        best_similarity = similarity
                        best_match = key_word
    return best_match



# Apply the get_best_match function to the ngrams column for bed sizes
#df['bed_size'] = df['ngrams'].apply(lambda x: get_best_match(x, bed_size_key_words))

# Apply the get_best_match function to the ngrams column for room styles
df['room_style'] = df['ngrams'].apply(lambda x: get_best_match(x, room_style_key_words))

# %%
df.tail(5)
# Out:
#       Vervotech ID  SupplierHotelId SupplierName      GroupId  \
# 1952      41268569           907505    HotelBeds  41268569-11
# 1953      41268569           907505    HotelBeds  41268569-12
# 1954      41268569           907505    HotelBeds  41268569-13
# 1955      41268569           907505    HotelBeds  41268569-14
# 1956      41268569           907505    HotelBeds  41268569-15
#
#      HotelBeds RoomCode                       HotelBeds RoomName  \
# 1952             TWN.H6             2 QUEEN BEDS ACCESSIBLE ROOM
# 1953          TWN.2Q-CV               2 QUEEN BED CITY VIEW ROOM
# 1954             ROO.CV        1 BED ROOM CITY VIEW WITH BALCONY
# 1955          SUI.B1-KG               1 KING BED 1 BEDROOM SUITE
# 1956             SUI.KG  1 KING BED 1 BEDROOM SUITE WITH BALCONY
#
#       Vervotech MappedStandardName                               room_type  \
# 1952    Room - 2 Queen, Accessible                2   Beds Accessible Room
# 1953     Room - 2 Queen, City View                  2   Bed City View Room
# 1954  Room With City View, Balcony      1  Bed Room City View With Balcony
# 1955              Suite, 1 Bedroom               1   Bed  1  Bedroom Suite
# 1956     Suite, 1 Bedroom, Balcony  1   Bed  1  Bedroom Suite With Balcony
#
#                                                  ngrams  bed_count  \
# 1952  [2, Queen, Beds, Accessible, Room, 2 Queen, Qu...          2
# 1953  [2, Queen, Bed, City, View, Room, 2 Queen, Que...          2
# 1954  [1, Bed, Room, City, View, With, Balcony, 1 Be...          1
# 1955  [1, King, Bed, 1, Bedroom, Suite, 1 King, King...          1
# 1956  [1, King, Bed, 1, Bedroom, Suite, With, Balcon...          1
#
#                                  room_type_1 room_style_1 bed_size room_style  \
# 1952                2   Beds Accessible Room                 Queen
# 1953                  2   Bed City View Room                 Queen
# 1954      1  Bed Room City View With Balcony                  None
# 1955               1   Bed  1  Bedroom Suite                  King
# 1956  1   Bed  1  Bedroom Suite With Balcony                  King
#
#       no_of_person  no_of_people
# 1952           NaN           4.0
# 1953           NaN           4.0
# 1954           NaN           1.0
# 1955           NaN           2.0
# 1956           NaN           2.0

# %%
#df['room_type_1'] = df['room_type']

# %%
# df['Vevotech Naming'] = df['Vervotech MappedStandardName']
# df['hotelRoomType'] = df['room_type']

# %%
df.head(100)
# Out:
#     Vervotech ID  SupplierHotelId SupplierName      GroupId  \
# 0       15111741           782331    HotelBeds   15111741-1
# 1       15111788           782334    HotelBeds   15111788-1
# 2       15131097           782325    HotelBeds   15131097-1
# 3       15294880           766775    HotelBeds   15294880-1
# 4       15294880           766775    HotelBeds   15294880-2
# ..           ...              ...          ...          ...
# 95      15780037           145605    HotelBeds   15780037-9
# 96      15780037           145605    HotelBeds  15780037-10
# 97      15780037           145605    HotelBeds  15780037-11
# 98      15780037           145605    HotelBeds  15780037-12
# 99      15780037           145605    HotelBeds  15780037-12
#
#    HotelBeds RoomCode          HotelBeds RoomName  \
# 0           APT.KG-PE  APARTMENT PREMIER KING BED
# 1              APT.2K       APARTMENT 2 KING BEDS
# 2              APT.KG     APARTMENT KING SIZE BED
# 3              DBL.QN       DOUBLE QUEEN SIZE BED
# 4            SUI.KG-1         SUITE KING SIZE BED
# ..                ...                         ...
# 95             DBL.EY              DOUBLE ECONOMY
# 96             DBL.KG        DOUBLE KING SIZE BED
# 97             SUI.LO                  SUITE LOFT
# 98             ROO.PE                Room PREMIER
# 99           DBL.PE-5              DOUBLE PREMIER
#
#    Vervotech MappedStandardName               room_type  \
# 0             Apartment Premier  Apartment Premier  Bed
# 1                     Apartment     Apartment  2   Beds
# 2                     Apartment     Apartment  Size Bed
# 3                    Queen Room        Double  Size Bed
# 4                         Suite         Suite  Size Bed
# ..                          ...                     ...
# 95                      Economy          Double Economy
# 96                    King Room        Double  Size Bed
# 97                   Loft Suite              Suite Loft
# 98                      Premier            Room Premier
# 99                      Premier          Double Premier
#
#                                                ngrams  bed_count  \
# 0   [Apartment, Premier, King, Bed, Apartment Prem...          1
# 1   [Apartment, 2, King, Beds, Apartment 2, 2 King...          2
# 2   [Apartment, King, Size, Bed, Apartment King, K...          1
# 3   [Double, Queen, Size, Bed, Double Queen, Queen...          1
# 4   [Suite, King, Size, Bed, Suite King, King Size...          1
# ..                                                ...        ...
# 95                  [Double, Economy, Double Economy]          1
# 96  [Double, King, Size, Bed, Double King, King Si...          1
# 97                          [Suite, Loft, Suite Loft]          1
# 98                      [Room, Premier, Room Premier]          1
# 99                  [Double, Premier, Double Premier]          1
#
#                room_type_1 room_style_1 bed_size room_style  no_of_person  \
# 0   Apartment Premier  Bed                  King    Premier           NaN
# 1      Apartment  2   Beds                  King                      NaN
# 2      Apartment  Size Bed                  King                      NaN
# 3                 Size Bed       Double    Queen                      2.0
# 4          Suite  Size Bed                  King                      NaN
# ..                     ...          ...      ...        ...           ...
# 95                 Economy       Double     None    Economy           2.0
# 96                Size Bed       Double     King                      2.0
# 97              Suite Loft                  None                      NaN
# 98            Room Premier                  None    Premier           NaN
# 99                 Premier       Double     None    Premier           2.0
#
#     no_of_people
# 0            2.0
# 1            4.0
# 2            2.0
# 3            2.0
# 4            2.0
# ..           ...
# 95           2.0
# 96           2.0
# 97           1.0
# 98           2.0
# 99           2.0
#
# [100 rows x 16 columns]

# %%
# fill empty values in the "bed_type" column with corresponding values in "bed_type_1"
#df['room_style'] = df.apply(lambda x: x['room_style_1'] if x['room_style'] == '' else x['room_style'], axis=1)

# %%
df.head(5)
# Out:
#    Vervotech ID  SupplierHotelId SupplierName     GroupId HotelBeds RoomCode  \
# 0      15111741           782331    HotelBeds  15111741-1          APT.KG-PE
# 1      15111788           782334    HotelBeds  15111788-1             APT.2K
# 2      15131097           782325    HotelBeds  15131097-1             APT.KG
# 3      15294880           766775    HotelBeds  15294880-1             DBL.QN
# 4      15294880           766775    HotelBeds  15294880-2           SUI.KG-1
#
#            HotelBeds RoomName Vervotech MappedStandardName  \
# 0  APARTMENT PREMIER KING BED            Apartment Premier
# 1       APARTMENT 2 KING BEDS                    Apartment
# 2     APARTMENT KING SIZE BED                    Apartment
# 3       DOUBLE QUEEN SIZE BED                   Queen Room
# 4         SUITE KING SIZE BED                        Suite
#
#                 room_type                                             ngrams  \
# 0  Apartment Premier  Bed  [Apartment, Premier, King, Bed, Apartment Prem...
# 1     Apartment  2   Beds  [Apartment, 2, King, Beds, Apartment 2, 2 King...
# 2     Apartment  Size Bed  [Apartment, King, Size, Bed, Apartment King, K...
# 3        Double  Size Bed  [Double, Queen, Size, Bed, Double Queen, Queen...
# 4         Suite  Size Bed  [Suite, King, Size, Bed, Suite King, King Size...
#
#    bed_count             room_type_1 room_style_1 bed_size room_style  \
# 0          1  Apartment Premier  Bed                  King    Premier
# 1          2     Apartment  2   Beds                  King
# 2          1     Apartment  Size Bed                  King
# 3          1                Size Bed       Double    Queen
# 4          1         Suite  Size Bed                  King
#
#    no_of_person  no_of_people
# 0           NaN           2.0
# 1           NaN           4.0
# 2           NaN           2.0
# 3           2.0           2.0
# 4           NaN           2.0

# %%
# add a new column "no_of_person" with values from "bed_count" column
#df['no_of_person'] = df['bed_count']

df.loc[df['room_style_1'] == 'Double', 'no_of_person'] = 2
df.loc[df['room_style_1'] == 'Triple', 'no_of_person'] = 3
df.loc[df['room_style_1'] == 'Quadruple', 'no_of_person'] = 4

# %%
# update the no_of_people column where room_style is king, queen or premium
df.loc[df['bed_size'].isin(['King', 'Queen', 'premium','Premium',  'Full', 'Sofa', 'Bunk']), 'no_of_people'] = df['bed_count'] * 2

# update the no_of_people column for other room_style values
df.loc[~df['bed_size'].isin(['King', 'Queen', 'premium','Premium',  'Full', 'Sofa', 'Bunk']), 'no_of_people'] = df['bed_count'] * 1

# %%
df.head(15)
# Out:
#     Vervotech ID  SupplierHotelId SupplierName     GroupId HotelBeds RoomCode  \
# 0       15111741           782331    HotelBeds  15111741-1          APT.KG-PE
# 1       15111788           782334    HotelBeds  15111788-1             APT.2K
# 2       15131097           782325    HotelBeds  15131097-1             APT.KG
# 3       15294880           766775    HotelBeds  15294880-1             DBL.QN
# 4       15294880           766775    HotelBeds  15294880-2           SUI.KG-1
# 5       15324900           141230    HotelBeds  15324900-1          DBL.2Q-DX
# 6       15324900           141230    HotelBeds  15324900-1          ROO.2Q-DX
# 7       15324900           141230    HotelBeds  15324900-2          DBL.DX-KG
# 8       15324900           141230    HotelBeds  15324900-3             DBL.KG
# 9       15324900           141230    HotelBeds  15324900-4          DBL.H6-KG
# 10      15324900           141230    HotelBeds  15324900-5          DBL.CV-KG
# 11      15324900           141230    HotelBeds  15324900-6          QUA.2Q-NM
# 12      15324900           141230    HotelBeds  15324900-7          DBL.NM-QN
# 13      15324900           141230    HotelBeds  15324900-7          ROO.NM-QN
# 14      15324900           141230    HotelBeds  15324900-7             DBL.QN
#
#                         HotelBeds RoomName Vervotech MappedStandardName  \
# 0               APARTMENT PREMIER KING BED            Apartment Premier
# 1                    APARTMENT 2 KING BEDS                    Apartment
# 2                  APARTMENT KING SIZE BED                    Apartment
# 3                    DOUBLE QUEEN SIZE BED                   Queen Room
# 4                      SUITE KING SIZE BED                        Suite
# 5             2 Queen Beds Deluxe Nonsmoke              Deluxe, 2 Queen
# 6             2 QUEEN BEDS DELUXE NONSMOKE              Deluxe, 2 Queen
# 7   King Deluxe Accessible Roll Shwr Nosmk     Deluxe, King, Accessible
# 8                    KING LEISURE NONSMOKE                    King Room
# 9          DOUBLE Accessible KING SIZE BED        King Room, Accessible
# 10               DOUBLE CITY VIEW KING BED         King Room, City View
# 11      QUADRUPLE 2 QUEEN BEDS NON SMOKING               Quadruple Room
# 12                  1 QUEEN BED NONSMOKING                   Queen Room
# 13              Room QUEEN BED NON SMOKING                   Queen Room
# 14                   DOUBLE QUEEN SIZE BED                   Queen Room
#
#                             room_type  \
# 0              Apartment Premier  Bed
# 1                 Apartment  2   Beds
# 2                 Apartment  Size Bed
# 3                    Double  Size Bed
# 4                     Suite  Size Bed
# 5            2   Beds Deluxe Nonsmoke
# 6            2   Beds Deluxe Nonsmoke
# 7   Deluxe Accessible Roll Shwr Nosmk
# 8                    Leisure Nonsmoke
# 9         Double Accessible  Size Bed
# 10              Double City View  Bed
# 11    Quadruple  2   Beds Non Smoking
# 12                 1   Bed Nonsmoking
# 13              Room  Bed Non Smoking
# 14                   Double  Size Bed
#
#                                                ngrams  bed_count  \
# 0   [Apartment, Premier, King, Bed, Apartment Prem...          1
# 1   [Apartment, 2, King, Beds, Apartment 2, 2 King...          2
# 2   [Apartment, King, Size, Bed, Apartment King, K...          1
# 3   [Double, Queen, Size, Bed, Double Queen, Queen...          1
# 4   [Suite, King, Size, Bed, Suite King, King Size...          1
# 5   [2, Queen, Beds, Deluxe, Nonsmoke, 2 Queen, Qu...          2
# 6   [2, Queen, Beds, Deluxe, Nonsmoke, 2 Queen, Qu...          2
# 7   [King, Deluxe, Accessible, Roll, Shwr, Nosmk, ...          1
# 8   [King, Leisure, Nonsmoke, King Leisure, Leisur...          1
# 9   [Double, Accessible, King, Size, Bed, Double A...          1
# 10  [Double, City, View, King, Bed, Double City, C...          1
# 11  [Quadruple, 2, Queen, Beds, Non, Smoking, Quad...          2
# 12  [1, Queen, Bed, Nonsmoking, 1 Queen, Queen Bed...          1
# 13  [Room, Queen, Bed, Non, Smoking, Room Queen, Q...          1
# 14  [Double, Queen, Size, Bed, Double Queen, Queen...          1
#
#                           room_type_1 room_style_1 bed_size room_style  \
# 0              Apartment Premier  Bed                  King    Premier
# 1                 Apartment  2   Beds                  King
# 2                 Apartment  Size Bed                  King
# 3                            Size Bed       Double    Queen
# 4                     Suite  Size Bed                  King
# 5            2   Beds Deluxe Nonsmoke                 Queen     Deluxe
# 6            2   Beds Deluxe Nonsmoke                 Queen     Deluxe
# 7   Deluxe Accessible Roll Shwr Nosmk                  King     Deluxe
# 8                    Leisure Nonsmoke                  King    Leisure
# 9                Accessible  Size Bed       Double     King
# 10                     City View  Bed       Double     King
# 11               2   Beds Non Smoking    Quadruple    Queen
# 12                 1   Bed Nonsmoking                 Queen
# 13              Room  Bed Non Smoking                 Queen
# 14                           Size Bed       Double    Queen
#
#     no_of_person  no_of_people
# 0            NaN           2.0
# 1            NaN           4.0
# 2            NaN           2.0
# 3            2.0           2.0
# 4            NaN           2.0
# 5            NaN           4.0
# 6            NaN           4.0
# 7            NaN           2.0
# 8            NaN           2.0
# 9            2.0           2.0
# 10           2.0           2.0
# 11           4.0           4.0
# 12           NaN           2.0
# 13           NaN           2.0
# 14           2.0           2.0

# %%
df['bed_size'].unique()
# Out:
# array(['King', 'Queen', None, 'Single', 'Twin', 'Queens', 'Full', 'Sofa',
#        'Bunk'], dtype=object)

# %%
# replace blank values in room_style column with room_style_1 values
df.loc[df['room_style'] == '', 'room_style'] = df.loc[df['room_style'] == '', 'room_style_1']

# %%
# find the maximum value between no_of_person and no_of_people columns
df['no_of_people'] = df[['no_of_person', 'no_of_people']].max(axis=1)

# %%
# replace bed_count with 2 where no_of_people is 4 and bed_count is 1
df.loc[(df['no_of_people'] == 4) & (df['bed_count'] == 1), 'bed_count'] = 2

# %%
# replace null values in bed_size column with room_style_1 values
df.loc[(df['bed_size'].isnull()) & (df['room_style_1'].isin(['Double', 'Triple'])), 'bed_size'] = df['room_style_1']

# %%
# replace null values in bed_size column with 'King' if room_style column has any of the specified values
df.loc[(df['bed_size'].isnull()) & (df['room_style'].isin(['Apartment', 'Suite', 'Leisure', 'Standard', 'Executive', 'Economy', 'Premier', 'Superior', 'Studio', 'Villa', 'Penthouse'])), 'bed_size'] = 'King'

df.loc[(df['bed_size'].isnull()) & (df['room_style'].isin(['Deluxe', 'Club'])), 'bed_size'] = 'Queen'

df.loc[(df['bed_size'].isnull()) & (df['room_style'].isin(['Dormitory' ])), 'bed_size'] = 'Single'

# %%
# update the 'no_of_people' column based on the condition
df.loc[(df['no_of_people']/df['bed_count'] == 1) & (df['bed_size'].isin(['King', 'Queen','Queens','Twin', 'Double'])), 'no_of_people'] = df['bed_count'] * 2

# %%
df['bed_size'].unique()
# Out:
# array(['King', 'Queen', None, 'Double', 'Single', 'Twin', 'Triple',
#        'Queens', 'Full', 'Sofa', 'Bunk'], dtype=object)

# %%
# df1 = df[(df['bed_count'] == 1)]
# df1

# %%
df1 = df[(df['room_style'] == 'Penthouse') & (df['bed_size'].isnull())]
df1
# Out:
# Empty DataFrame
# Columns: [Vervotech ID, SupplierHotelId, SupplierName, GroupId, HotelBeds RoomCode, HotelBeds RoomName, Vervotech MappedStandardName, room_type, ngrams, bed_count, room_type_1, room_style_1, bed_size, room_style, no_of_person, no_of_people]
# Index: []

# %%
(df['no_of_people'][110] /df['bed_count'][110])== 1
# Out:
# True

# %%
df1 = df[(df['bed_size'] == 'Twin') & (df['bed_count'] == 2) ]
df1
# Out:
#       Vervotech ID  SupplierHotelId SupplierName      GroupId  \
# 57        15471297            45947    HotelBeds  15471297-16
# 145       15382506            42990    HotelBeds   15382506-7
# 155       15382506            42990    HotelBeds  15382506-14
# 157       15382506            42990    HotelBeds  15382506-14
# 413       38380068           589938    HotelBeds  38380068-16
# 435       38751099            13046    HotelBeds   38751099-9
# 466       38751099            13046    HotelBeds  38751099-35
# 509       38751099            13046    HotelBeds  38751099-69
# 615       39091738            16145    HotelBeds  39091738-16
# 633       39091739            16182    HotelBeds   39091739-7
# 721       39600932           251774    HotelBeds  39600932-14
# 722       39600932           251774    HotelBeds  39600932-15
# 751       39601097           426321    HotelBeds   39601097-6
# 871       39603752           251781    HotelBeds   39603752-7
# 1013      39626628           278222    HotelBeds   39626628-4
# 1114      39643859            39219    HotelBeds  39643859-14
# 1215      39649457            16836    HotelBeds  39649457-12
# 1231      39650469            16137    HotelBeds   39650469-3
# 1303      39658032            29251    HotelBeds   39658032-5
# 1304      39658032            29251    HotelBeds   39658032-5
# 1366      39664611           417318    HotelBeds   39664611-3
# 1498      39675048           128424    HotelBeds   39675048-6
#
#      HotelBeds RoomCode                     HotelBeds RoomName  \
# 57            TWN.2D-CV           TWIN CITY VIEW 2 DOUBLE BEDS
# 145              TWN.2D                     TWIN 2 DOUBLE BEDS
# 155           DBT.2D-SU  Double or Twin SUPERIOR 2 DOUBLE BEDS
# 157           TWN.2D-SU            TWIN SUPERIOR 2 DOUBLE BEDS
# 413            DBT.2D-6           Double or Twin 2 DOUBLE BEDS
# 435           TWN.2D-DX              TWIN DELUXE 2 DOUBLE BEDS
# 466              TWN.2D                     TWIN 2 DOUBLE BEDS
# 509           DBT.2D-SU  Double or Twin SUPERIOR 2 DOUBLE BEDS
# 615              TWN.2D                     TWIN 2 DOUBLE BEDS
# 633           TWN.2D-EJ           TWIN EXECUTIVE 2 DOUBLE BEDS
# 721              TWN.2D                     TWIN 2 DOUBLE BEDS
# 722           TWN.2D-CV           TWIN CITY VIEW 2 DOUBLE BEDS
# 751           TWN.2D-CV           TWIN CITY VIEW 2 DOUBLE BEDS
# 871              TWN.2D                     TWIN 2 DOUBLE BEDS
# 1013             TWN.2D                     TWIN 2 DOUBLE BEDS
# 1114             TWN.2D                     TWIN 2 DOUBLE BEDS
# 1215           TWN.2D-1                     TWIN 2 DOUBLE BEDS
# 1231          TWN.2D-DX              TWIN DELUXE 2 DOUBLE BEDS
# 1303          TWN.2D-DX              Twin Deluxe 2 double beds
# 1304          DBT.2D-DX    Double or Twin DELUXE 2 DOUBLE BEDS
# 1366             TWN.2B                            TWIN 2 BEDS
# 1498             TWN.2D                     TWIN 2 DOUBLE BEDS
#
#      Vervotech MappedStandardName                            room_type  \
# 57     Room - 2 Double, City View            City View  2  Double Beds
# 145               Room - 2 Double                       2  Double Beds
# 155            Superior, 2 Double  Double Or  Superior  2  Double Beds
# 157            Superior, 2 Double             Superior  2  Double Beds
# 413                Room - 2 Queen           Double Or   2  Double Beds
# 435              DELUXE, 2 Double               Deluxe  2  Double Beds
# 466               Room - 2 Double                       2  Double Beds
# 509            SUPERIOR, 2 Double  Double Or  Superior  2  Double Beds
# 615               Room - 2 Double                       2  Double Beds
# 633           Executive, 2 Double            Executive  2  Double Beds
# 721               Room - 2 Double                       2  Double Beds
# 722    Room - 2 Double, City View            City View  2  Double Beds
# 751    Room - 2 Double, City View            City View  2  Double Beds
# 871               Room - 2 Double                       2  Double Beds
# 1013              Room - 2 Double                       2  Double Beds
# 1114              Room - 2 Double                       2  Double Beds
# 1215              Room - 2 Double                       2  Double Beds
# 1231             Deluxe, 2 Double               Deluxe  2  Double Beds
# 1303             Deluxe, 2 Double               Deluxe  2  Double Beds
# 1304             Deluxe, 2 Double    Double Or  Deluxe  2  Double Beds
# 1366            DoubleOrTwin Room                              2  Beds
# 1498              Room - 2 Double                       2  Double Beds
#
#                                                  ngrams  bed_count  \
# 57    [Twin, City, View, 2, Double, Beds, Twin City,...          2
# 145   [Twin, 2, Double, Beds, Twin 2, 2 Double, Doub...          2
# 155   [Double, Or, Twin, Superior, 2, Double, Beds, ...          2
# 157   [Twin, Superior, 2, Double, Beds, Twin Superio...          2
# 413   [Double, Or, Twin, 2, Double, Beds, Double Or,...          2
# 435   [Twin, Deluxe, 2, Double, Beds, Twin Deluxe, D...          2
# 466   [Twin, 2, Double, Beds, Twin 2, 2 Double, Doub...          2
# 509   [Double, Or, Twin, Superior, 2, Double, Beds, ...          2
# 615   [Twin, 2, Double, Beds, Twin 2, 2 Double, Doub...          2
# 633   [Twin, Executive, 2, Double, Beds, Twin Execut...          2
# 721   [Twin, 2, Double, Beds, Twin 2, 2 Double, Doub...          2
# 722   [Twin, City, View, 2, Double, Beds, Twin City,...          2
# 751   [Twin, City, View, 2, Double, Beds, Twin City,...          2
# 871   [Twin, 2, Double, Beds, Twin 2, 2 Double, Doub...          2
# 1013  [Twin, 2, Double, Beds, Twin 2, 2 Double, Doub...          2
# 1114  [Twin, 2, Double, Beds, Twin 2, 2 Double, Doub...          2
# 1215  [Twin, 2, Double, Beds, Twin 2, 2 Double, Doub...          2
# 1231  [Twin, Deluxe, 2, Double, Beds, Twin Deluxe, D...          2
# 1303  [Twin, Deluxe, 2, Double, Beds, Twin Deluxe, D...          2
# 1304  [Double, Or, Twin, Deluxe, 2, Double, Beds, Do...          2
# 1366       [Twin, 2, Beds, Twin 2, 2 Beds, Twin 2 Beds]          2
# 1498  [Twin, 2, Double, Beds, Twin 2, 2 Double, Doub...          2
#
#                  room_type_1 room_style_1 bed_size room_style  no_of_person  \
# 57       City View  2   Beds       Double     Twin     Double           2.0
# 145                 2   Beds       Double     Twin     Double           2.0
# 155   Or  Superior  2   Beds       Double     Twin   Superior           2.0
# 157       Superior  2   Beds       Double     Twin   Superior           2.0
# 413            Or   2   Beds       Double     Twin     Double           2.0
# 435         Deluxe  2   Beds       Double     Twin     Deluxe           2.0
# 466                 2   Beds       Double     Twin     Double           2.0
# 509   Or  Superior  2   Beds       Double     Twin   Superior           2.0
# 615                 2   Beds       Double     Twin     Double           2.0
# 633      Executive  2   Beds       Double     Twin  Executive           2.0
# 721                 2   Beds       Double     Twin     Double           2.0
# 722      City View  2   Beds       Double     Twin     Double           2.0
# 751      City View  2   Beds       Double     Twin     Double           2.0
# 871                 2   Beds       Double     Twin     Double           2.0
# 1013                2   Beds       Double     Twin     Double           2.0
# 1114                2   Beds       Double     Twin     Double           2.0
# 1215                2   Beds       Double     Twin     Double           2.0
# 1231        Deluxe  2   Beds       Double     Twin     Deluxe           2.0
# 1303        Deluxe  2   Beds       Double     Twin     Deluxe           2.0
# 1304    Or  Deluxe  2   Beds       Double     Twin     Deluxe           2.0
# 1366                 2  Beds                  Twin                      NaN
# 1498                2   Beds       Double     Twin     Double           2.0
#
#       no_of_people
# 57             4.0
# 145            4.0
# 155            4.0
# 157            4.0
# 413            4.0
# 435            4.0
# 466            4.0
# 509            4.0
# 615            4.0
# 633            4.0
# 721            4.0
# 722            4.0
# 751            4.0
# 871            4.0
# 1013           4.0
# 1114           4.0
# 1215           4.0
# 1231           4.0
# 1303           4.0
# 1304           4.0
# 1366           4.0
# 1498           4.0

# %%
# group by bed_count, bed_size, room_style and get the count of records
grouped = df.groupby(['bed_count', 'room_style_1', 'bed_size', 'no_of_people']).size().reset_index(name='count')

grouped
# Out:
#     bed_count room_style_1 bed_size  no_of_people  count
# 0           1                  Full           2.0      8
# 1           1                  King           2.0    604
# 2           1                 Queen           2.0    123
# 3           1                Queens           2.0     18
# 4           1                Single           1.0     36
# 5           1                  Sofa           2.0      3
# 6           1                  Twin           2.0      6
# 7           1       Double     Bunk           2.0      1
# 8           1       Double   Double           2.0    314
# 9           1       Double     King           2.0    152
# 10          1       Double    Queen           2.0     54
# 11          1       Double   Single           2.0      3
# 12          1       Double     Twin           2.0     28
# 13          1       Triple     King           3.0      1
# 14          1       Triple    Queen           3.0      1
# 15          1       Triple   Triple           3.0      9
# 16          2                  King           4.0      9
# 17          2                 Queen           4.0     59
# 18          2                Queens           4.0      1
# 19          2                  Sofa           4.0      1
# 20          2                  Twin           4.0      1
# 21          2       Double   Double           4.0    137
# 22          2       Double    Queen           4.0     43
# 23          2       Double     Twin           4.0     21
# 24          2    Quadruple     King           4.0     10
# 25          2    Quadruple    Queen           4.0     37
# 26          2       Triple    Queen           4.0      1
# 27          2       Triple   Triple           3.0      1

# %%
grouped.head(25)
# Out:
#     bed_count room_style_1 bed_size  no_of_people  count
# 0           1                  Full           2.0      8
# 1           1                  King           2.0    604
# 2           1                 Queen           2.0    123
# 3           1                Queens           2.0     18
# 4           1                Single           1.0     36
# 5           1                  Sofa           2.0      3
# 6           1                  Twin           2.0      6
# 7           1       Double     Bunk           2.0      1
# 8           1       Double   Double           2.0    314
# 9           1       Double     King           2.0    152
# 10          1       Double    Queen           2.0     54
# 11          1       Double   Single           2.0      3
# 12          1       Double     Twin           2.0     28
# 13          1       Triple     King           3.0      1
# 14          1       Triple    Queen           3.0      1
# 15          1       Triple   Triple           3.0      9
# 16          2                  King           4.0      9
# 17          2                 Queen           4.0     59
# 18          2                Queens           4.0      1
# 19          2                  Sofa           4.0      1
# 20          2                  Twin           4.0      1
# 21          2       Double   Double           4.0    137
# 22          2       Double    Queen           4.0     43
# 23          2       Double     Twin           4.0     21
# 24          2    Quadruple     King           4.0     10

# %%
df.head(405)
# Out:
#      Vervotech ID  SupplierHotelId SupplierName      GroupId  \
# 0        15111741           782331    HotelBeds   15111741-1
# 1        15111788           782334    HotelBeds   15111788-1
# 2        15131097           782325    HotelBeds   15131097-1
# 3        15294880           766775    HotelBeds   15294880-1
# 4        15294880           766775    HotelBeds   15294880-2
# ..            ...              ...          ...          ...
# 400      38380068           589938    HotelBeds   38380068-7
# 401      38380068           589938    HotelBeds   38380068-8
# 402      38380068           589938    HotelBeds   38380068-8
# 403      38380068           589938    HotelBeds   38380068-9
# 404      38380068           589938    HotelBeds  38380068-10
#
#     HotelBeds RoomCode               HotelBeds RoomName  \
# 0            APT.KG-PE       APARTMENT PREMIER KING BED
# 1               APT.2K            APARTMENT 2 KING BEDS
# 2               APT.KG          APARTMENT KING SIZE BED
# 3               DBL.QN            DOUBLE QUEEN SIZE BED
# 4             SUI.KG-1              SUITE KING SIZE BED
# ..                 ...                              ...
# 400          DBL.KG-NM      DOUBLE KING BED NON SMOKING
# 401          DBL.H6-KG  DOUBLE Accessible KING SIZE BED
# 402          ROO.H6-KG    Room Accessible KING SIZE BED
# 403             ROO.ST                    STANDARD ROOM
# 404           TWN.KG-8               TWIN KING SIZE BED
#
#     Vervotech MappedStandardName                    room_type  \
# 0              Apartment Premier       Apartment Premier  Bed
# 1                      Apartment          Apartment  2   Beds
# 2                      Apartment          Apartment  Size Bed
# 3                     Queen Room             Double  Size Bed
# 4                          Suite              Suite  Size Bed
# ..                           ...                          ...
# 400                    King Room      Double  Bed Non Smoking
# 401        King Room, Accessible  Double Accessible  Size Bed
# 402        King Room, Accessible    Room Accessible  Size Bed
# 403              King/Queen Room                Standard Room
# 404               King/Twin Room               Twin  Size Bed
#
#                                                 ngrams  bed_count  \
# 0    [Apartment, Premier, King, Bed, Apartment Prem...          1
# 1    [Apartment, 2, King, Beds, Apartment 2, 2 King...          2
# 2    [Apartment, King, Size, Bed, Apartment King, K...          1
# 3    [Double, Queen, Size, Bed, Double Queen, Queen...          1
# 4    [Suite, King, Size, Bed, Suite King, King Size...          1
# ..                                                 ...        ...
# 400  [Double, King, Bed, Non, Smoking, Double King,...          1
# 401  [Double, Accessible, King, Size, Bed, Double A...          1
# 402  [Room, Accessible, King, Size, Bed, Room Acces...          1
# 403                    [Standard, Room, Standard Room]          1
# 404  [Twin, King, Size, Bed, Twin King, King Size, ...          1
#
#                        room_type_1 room_style_1 bed_size room_style  \
# 0       Apartment Premier King Bed                  King    Premier
# 1          Apartment  2  King Beds                  King
# 2          Apartment King Size Bed                  King
# 3                   Queen Size Bed       Double    Queen     Double
# 4              Suite King Size Bed                  King
# ..                             ...          ...      ...        ...
# 400           King Bed Non Smoking       Double     King     Double
# 401       Accessible King Size Bed       Double     King     Double
# 402  Room Accessible King Size Bed                  King
# 403                  Standard Room                  King   Standard
# 404             Twin King Size Bed                  King
#
#      no_of_person  no_of_people
# 0             NaN           2.0
# 1             NaN           4.0
# 2             NaN           2.0
# 3             2.0           2.0
# 4             NaN           2.0
# ..            ...           ...
# 400           2.0           2.0
# 401           2.0           2.0
# 402           NaN           2.0
# 403           NaN           2.0
# 404           NaN           2.0
#
# [405 rows x 16 columns]

# %%
df['room_style_1'][1]
# Out:
# ''

# %%
empty_values_count = df['room_style'].str.strip().eq('').sum()
empty_values_count
# Out:
# 347

# %%
df1 = df[(df['room_style_1'] == "Triple") & df['bed_count'] == 1]
df1
# Out:
#       Vervotech ID  SupplierHotelId SupplierName      GroupId  \
# 79        15504023           277857    HotelBeds   15504023-2
# 740       39600932           251774    HotelBeds  39600932-27
# 741       39600932           251774    HotelBeds  39600932-28
# 863       39603646           251773    HotelBeds   39603646-5
# 1123      39643859            39219    HotelBeds  39643859-18
# 1755      39732127           271877    HotelBeds  39732127-22
# 1855      40050192            13432    HotelBeds   40050192-6
# 1858      40050192            13432    HotelBeds   40050192-9
# 1861      40050192            13432    HotelBeds  40050192-11
# 1868      40050192            13432    HotelBeds  40050192-15
# 1906      40050192            13432    HotelBeds  40050192-42
#
#      HotelBeds RoomCode      HotelBeds RoomName  Vervotech MappedStandardName  \
# 79               TPL.PI          TRIPLE PREMIUM               Premium, Triple
# 740              TPL.SU         TRIPLE SUPERIOR              Superior, Triple
# 741              TPL.ST         TRIPLE STANDARD                   Triple Room
# 863              TPL.RO     TRIPLE RUN OF HOUSE          Run Of House, Triple
# 1123             TPL.ST         TRIPLE STANDARD                   Triple Room
# 1755           TPL.FH-1      Triple Shared Bath  Triple Room, Shared Bathroom
# 1855          TPL.CB-EJ   TRIPLE CLUB EXECUTIVE        Club Executive, Triple
# 1858             TPL.CB             TRIPLE CLUB                  Club, Triple
# 1861          TPL.DX-KG  TRIPLE DELUXE KING BED                  Deluxe, King
# 1868             TPL.DX           TRIPLE DELUXE                Deluxe, Triple
# 1906             TPL.QN   TRIPLE QUEEN SIZE BED                   Triple Room
#
#                   room_type  \
# 79                   Triple
# 740         Triple Superior
# 741         Triple Standard
# 863     Triple Run Of House
# 1123        Triple Standard
# 1755     Triple Shared Bath
# 1855  Triple Club Executive
# 1858            Triple Club
# 1861     Triple Deluxe  Bed
# 1868          Triple Deluxe
# 1906       Triple  Size Bed
#
#                                                  ngrams  bed_count  \
# 79                    [Triple, Premium, Triple Premium]          1
# 740                 [Triple, Superior, Triple Superior]          1
# 741                 [Triple, Standard, Triple Standard]          1
# 863   [Triple, Run, Of, House, Triple Run, Run Of, O...          1
# 1123                [Triple, Standard, Triple Standard]          1
# 1755  [Triple, Shared, Bath, Triple Shared, Shared B...          1
# 1855  [Triple, Club, Executive, Triple Club, Club Ex...          1
# 1858                        [Triple, Club, Triple Club]          1
# 1861  [Triple, Deluxe, King, Bed, Triple Deluxe, Del...          1
# 1868                    [Triple, Deluxe, Triple Deluxe]          1
# 1906  [Triple, Queen, Size, Bed, Triple Queen, Queen...          1
#
#           room_type_1 room_style_1 bed_size room_style  no_of_person  \
# 79            Premium       Triple  Premium     Triple           3.0
# 740          Superior       Triple   Triple   Superior           3.0
# 741          Standard       Triple   Triple   Standard           3.0
# 863      Run Of House       Triple   Triple     Triple           3.0
# 1123         Standard       Triple   Triple   Standard           3.0
# 1755      Shared Bath       Triple   Triple     Triple           3.0
# 1855   Club Executive       Triple   Triple       Club           3.0
# 1858             Club       Triple   Triple       Club           3.0
# 1861  Deluxe King Bed       Triple     King     Deluxe           3.0
# 1868           Deluxe       Triple   Triple     Deluxe           3.0
# 1906   Queen Size Bed       Triple    Queen     Triple           3.0
#
#       no_of_people
# 79             3.0
# 740            3.0
# 741            3.0
# 863            3.0
# 1123           3.0
# 1755           3.0
# 1855           3.0
# 1858           3.0
# 1861           3.0
# 1868           3.0
# 1906           3.0

# %%
df
# Out:
#       Vervotech ID  SupplierHotelId SupplierName      GroupId  \
# 0         15111741           782331    HotelBeds   15111741-1
# 1         15111788           782334    HotelBeds   15111788-1
# 2         15131097           782325    HotelBeds   15131097-1
# 3         15294880           766775    HotelBeds   15294880-1
# 4         15294880           766775    HotelBeds   15294880-2
# ...            ...              ...          ...          ...
# 1952      41268569           907505    HotelBeds  41268569-11
# 1953      41268569           907505    HotelBeds  41268569-12
# 1954      41268569           907505    HotelBeds  41268569-13
# 1955      41268569           907505    HotelBeds  41268569-14
# 1956      41268569           907505    HotelBeds  41268569-15
#
#      HotelBeds RoomCode                       HotelBeds RoomName  \
# 0             APT.KG-PE               APARTMENT PREMIER KING BED
# 1                APT.2K                    APARTMENT 2 KING BEDS
# 2                APT.KG                  APARTMENT KING SIZE BED
# 3                DBL.QN                    DOUBLE QUEEN SIZE BED
# 4              SUI.KG-1                      SUITE KING SIZE BED
# ...                 ...                                      ...
# 1952             TWN.H6             2 QUEEN BEDS ACCESSIBLE ROOM
# 1953          TWN.2Q-CV               2 QUEEN BED CITY VIEW ROOM
# 1954             ROO.CV        1 BED ROOM CITY VIEW WITH BALCONY
# 1955          SUI.B1-KG               1 KING BED 1 BEDROOM SUITE
# 1956             SUI.KG  1 KING BED 1 BEDROOM SUITE WITH BALCONY
#
#       Vervotech MappedStandardName                               room_type  \
# 0                Apartment Premier                  Apartment Premier  Bed
# 1                        Apartment                     Apartment  2   Beds
# 2                        Apartment                     Apartment  Size Bed
# 3                       Queen Room                        Double  Size Bed
# 4                            Suite                         Suite  Size Bed
# ...                            ...                                     ...
# 1952    Room - 2 Queen, Accessible                2   Beds Accessible Room
# 1953     Room - 2 Queen, City View                  2   Bed City View Room
# 1954  Room With City View, Balcony      1  Bed Room City View With Balcony
# 1955              Suite, 1 Bedroom               1   Bed  1  Bedroom Suite
# 1956     Suite, 1 Bedroom, Balcony  1   Bed  1  Bedroom Suite With Balcony
#
#                                                  ngrams  bed_count  \
# 0     [Apartment, Premier, King, Bed, Apartment Prem...          1
# 1     [Apartment, 2, King, Beds, Apartment 2, 2 King...          2
# 2     [Apartment, King, Size, Bed, Apartment King, K...          1
# 3     [Double, Queen, Size, Bed, Double Queen, Queen...          1
# 4     [Suite, King, Size, Bed, Suite King, King Size...          1
# ...                                                 ...        ...
# 1952  [2, Queen, Beds, Accessible, Room, 2 Queen, Qu...          2
# 1953  [2, Queen, Bed, City, View, Room, 2 Queen, Que...          2
# 1954  [1, Bed, Room, City, View, With, Balcony, 1 Be...          1
# 1955  [1, King, Bed, 1, Bedroom, Suite, 1 King, King...          1
# 1956  [1, King, Bed, 1, Bedroom, Suite, With, Balcon...          1
#
#                                       room_type_1 room_style_1 bed_size  \
# 0                      Apartment Premier King Bed                  King
# 1                         Apartment  2  King Beds                  King
# 2                         Apartment King Size Bed                  King
# 3                                  Queen Size Bed       Double    Queen
# 4                             Suite King Size Bed                  King
# ...                                           ...          ...      ...
# 1952                2  Queen Beds Accessible Room                 Queen
# 1953                  2  Queen Bed City View Room                 Queen
# 1954           1  Bed Room City View With Balcony                  None
# 1955                1  King Bed  1  Bedroom Suite                  King
# 1956   1  King Bed  1  Bedroom Suite With Balcony                  King
#
#      room_style  no_of_person  no_of_people
# 0     Apartment           NaN           2.0
# 1     Apartment           NaN           4.0
# 2     Apartment           NaN           2.0
# 3        Double           2.0           2.0
# 4         Suite           NaN           2.0
# ...         ...           ...           ...
# 1952                      NaN           4.0
# 1953                      NaN           4.0
# 1954                      NaN           1.0
# 1955      Suite           NaN           2.0
# 1956      Suite           NaN           2.0
#
# [1957 rows x 16 columns]

# %%
# df.loc[df['room_style'] == '', 'room_style'] = 'Standard'
# df.loc[df['bed_size'] == '', 'bed_size'] = 'Single'

# %%
#df.to_csv("test_5.csv")

# %%
from pivottablejs import pivot_ui
pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#df = pd.read_csv("test_5.csv")

# %%
df.head(5)
# Out:
#    Vervotech ID  SupplierHotelId SupplierName     GroupId HotelBeds RoomCode  \
# 0      15111741           782331    HotelBeds  15111741-1          APT.KG-PE
# 1      15111788           782334    HotelBeds  15111788-1             APT.2K
# 2      15131097           782325    HotelBeds  15131097-1             APT.KG
# 3      15294880           766775    HotelBeds  15294880-1             DBL.QN
# 4      15294880           766775    HotelBeds  15294880-2           SUI.KG-1
#
#            HotelBeds RoomName Vervotech MappedStandardName  \
# 0  APARTMENT PREMIER KING BED            Apartment Premier
# 1       APARTMENT 2 KING BEDS                    Apartment
# 2     APARTMENT KING SIZE BED                    Apartment
# 3       DOUBLE QUEEN SIZE BED                   Queen Room
# 4         SUITE KING SIZE BED                        Suite
#
#                 room_type                                             ngrams  \
# 0  Apartment Premier  Bed  [Apartment, Premier, King, Bed, Apartment Prem...
# 1     Apartment  2   Beds  [Apartment, 2, King, Beds, Apartment 2, 2 King...
# 2     Apartment  Size Bed  [Apartment, King, Size, Bed, Apartment King, K...
# 3        Double  Size Bed  [Double, Queen, Size, Bed, Double Queen, Queen...
# 4         Suite  Size Bed  [Suite, King, Size, Bed, Suite King, King Size...
#
#    bed_count                 room_type_1 room_style_1 bed_size room_style  \
# 0          1  Apartment Premier King Bed                  King  Apartment
# 1          2     Apartment  2  King Beds                  King  Apartment
# 2          1     Apartment King Size Bed                  King  Apartment
# 3          1              Queen Size Bed       Double    Queen     Double
# 4          1         Suite King Size Bed                  King      Suite
#
#    no_of_person  no_of_people
# 0           NaN           2.0
# 1           NaN           4.0
# 2           NaN           2.0
# 3           2.0           2.0
# 4           NaN           2.0

# %%
df1 = pd.read_csv("Niranjani_test_set.csv")
df2 = pd.read_csv("Nileka_test_set.csv")
df3 = pd.read_csv("saumya_test_set_Updated.csv")
df4 = pd.read_csv("Nuwan_test_set.csv")

# %%
merged_df = pd.concat([df1, df2, df3, df4], axis=0, ignore_index=True)
merged_df = merged_df.drop(['Unnamed: 11','Unnamed: 9','Unnamed: 10'], axis=1)
df1 = merged_df

# Merge the dataframes based on the index of df and the "Unnamed: 0" column of df1
merged_df = pd.merge(df, df1[['Unnamed: 0', 'Label', 'Remarks']], left_index=True, right_on='Unnamed: 0')

# %%
merged_df
# Out:
#      Vervotech ID  SupplierHotelId SupplierName      GroupId  \
# 0        15780037           145605    HotelBeds  15780037-13
# 1        15780037           145605    HotelBeds  15780037-14
# 2        15780037           145605    HotelBeds  15780037-15
# 3        15780037           145605    HotelBeds  15780037-16
# 4        15780037           145605    HotelBeds  15780037-17
# ..            ...              ...          ...          ...
# 395      38751099            13046    HotelBeds  38751099-60
# 396      38751099            13046    HotelBeds  38751099-60
# 397      38751099            13046    HotelBeds  38751099-61
# 398      38751099            13046    HotelBeds  38751099-61
# 399      38751099            13046    HotelBeds  38751099-61
#
#     HotelBeds RoomCode                       HotelBeds RoomName  \
# 0               DBL.PE  Premier Skyline View Room, 2 Queen Beds
# 1            DBL.KG-PE      Premier Skyline View Room, King Bed
# 2               QUA.H6                     QUADRUPLE Accessible
# 3               ROO.RO                        Room RUN OF HOUSE
# 4               SUI.ST                           SUITE STANDARD
# ..                 ...                                      ...
# 395             SUI.SU                           SUITE SUPERIOR
# 396          SUI.2D-SU             SUITE SUPERIOR 2 DOUBLE BEDS
# 397             SUI.B1                          1-Bedroom Suite
# 398           SUI.B1-3                          SUITE 1 BEDROOM
# 399          SUI.B1-KG                 SUITE KING BED 1 BEDROOM
#
#        Vervotech MappedStandardName                             room_type  \
# 0    Premier, 2 Queen, Skyline View  Premier Skyline View Room,  2   Beds
# 1       Premier, King, Skyline View       Premier Skyline View Room,  Bed
# 2        Quadruple Room, Accessible                  Quadruple Accessible
# 3                      Run Of House                     Room Run Of House
# 4                             Suite                        Suite Standard
# ..                              ...                                   ...
# 395                  Suite Superior                        Suite Superior
# 396                  Suite Superior        Suite Superior  2  Double Beds
# 397                Suite, 1 Bedroom                      1  Bedroom Suite
# 398                Suite, 1 Bedroom                     Suite  1  Bedroom
# 399                Suite, 1 Bedroom                Suite  Bed  1  Bedroom
#
#                                                 ngrams  bed_count  \
# 0    [Premier, Skyline, View, Room,, 2, Queen, Beds...          2
# 1    [Premier, Skyline, View, Room,, King, Bed, Pre...          1
# 2        [Quadruple, Accessible, Quadruple Accessible]          2
# 3    [Room, Run, Of, House, Room Run, Run Of, Of Ho...          1
# 4                    [Suite, Standard, Suite Standard]          1
# ..                                                 ...        ...
# 395                  [Suite, Superior, Suite Superior]          1
# 396  [Suite, Superior, 2, Double, Beds, Suite Super...          2
# 397  [1, Bedroom, Suite, 1 Bedroom, Bedroom Suite, ...          1
# 398  [Suite, 1, Bedroom, Suite 1, 1 Bedroom, Suite ...          1
# 399  [Suite, King, Bed, 1, Bedroom, Suite King, Kin...          1
#
#                                    room_type_1 room_style_1 bed_size  \
# 0    Premier Skyline View Room,  2  Queen Beds                 Queen
# 1          Premier Skyline View Room, King Bed                  King
# 2                                   Accessible    Quadruple     None
# 3                            Room Run Of House                  None
# 4                               Suite Standard                  King
# ..                                         ...          ...      ...
# 395                             Suite Superior                  King
# 396                   Suite Superior  2   Beds       Double   Double
# 397                           1  Bedroom Suite                  King
# 398                          Suite  1  Bedroom                  King
# 399                 Suite King Bed  1  Bedroom                  King
#
#     room_style  no_of_person  no_of_people  Unnamed: 0 Label  \
# 0      Premier           NaN           4.0         100  -1.0
# 1      Premier           NaN           2.0         101  -1.0
# 2    Quadruple           4.0           4.0         102  -1.0
# 3                        NaN           1.0         103   NaN
# 4        Suite           NaN           2.0         104   0.0
# ..         ...           ...           ...         ...   ...
# 395      Suite           NaN           2.0         495     0
# 396      Suite           2.0           4.0         496     0
# 397      Suite           NaN           2.0         497     0
# 398      Suite           NaN           2.0         498     0
# 399      Suite           NaN           2.0         499     0
#
#                                                Remarks
# 0                 2 queen bed can accommodate 4 people
# 1                            no. of people should be 2
# 2    Bed size cannot be single, if it accommadate f...
# 3                                                  NaN
# 4    suites normaly with king/queen/double/twon bed...
# ..                                                 ...
# 395                                             -same-
# 396                                             -same-
# 397                      does the sweet have a bedroom
# 398                               suite have a bedroom
# 399                                             -same-
#
# [400 rows x 19 columns]

# %%
merged_df = merged_df.drop(['SupplierHotelId','SupplierName','GroupId' ,'HotelBeds RoomCode','room_type','Vervotech MappedStandardName', 'room_type_1','room_style_1','no_of_person','Unnamed: 0'], axis=1)

# %%
merged_df
# Out:
#      Vervotech ID                       HotelBeds RoomName  \
# 0        15780037  Premier Skyline View Room, 2 Queen Beds
# 1        15780037      Premier Skyline View Room, King Bed
# 2        15780037                     QUADRUPLE Accessible
# 3        15780037                        Room RUN OF HOUSE
# 4        15780037                           SUITE STANDARD
# ..            ...                                      ...
# 395      38751099                           SUITE SUPERIOR
# 396      38751099             SUITE SUPERIOR 2 DOUBLE BEDS
# 397      38751099                          1-Bedroom Suite
# 398      38751099                          SUITE 1 BEDROOM
# 399      38751099                 SUITE KING BED 1 BEDROOM
#
#                                                 ngrams  bed_count bed_size  \
# 0    [Premier, Skyline, View, Room,, 2, Queen, Beds...          2    Queen
# 1    [Premier, Skyline, View, Room,, King, Bed, Pre...          1     King
# 2        [Quadruple, Accessible, Quadruple Accessible]          2     None
# 3    [Room, Run, Of, House, Room Run, Run Of, Of Ho...          1     None
# 4                    [Suite, Standard, Suite Standard]          1     King
# ..                                                 ...        ...      ...
# 395                  [Suite, Superior, Suite Superior]          1     King
# 396  [Suite, Superior, 2, Double, Beds, Suite Super...          2   Double
# 397  [1, Bedroom, Suite, 1 Bedroom, Bedroom Suite, ...          1     King
# 398  [Suite, 1, Bedroom, Suite 1, 1 Bedroom, Suite ...          1     King
# 399  [Suite, King, Bed, 1, Bedroom, Suite King, Kin...          1     King
#
#     room_style  no_of_people Label  \
# 0      Premier           4.0  -1.0
# 1      Premier           2.0  -1.0
# 2    Quadruple           4.0  -1.0
# 3                        1.0   NaN
# 4        Suite           2.0   0.0
# ..         ...           ...   ...
# 395      Suite           2.0     0
# 396      Suite           4.0     0
# 397      Suite           2.0     0
# 398      Suite           2.0     0
# 399      Suite           2.0     0
#
#                                                Remarks
# 0                 2 queen bed can accommodate 4 people
# 1                            no. of people should be 2
# 2    Bed size cannot be single, if it accommadate f...
# 3                                                  NaN
# 4    suites normaly with king/queen/double/twon bed...
# ..                                                 ...
# 395                                             -same-
# 396                                             -same-
# 397                      does the sweet have a bedroom
# 398                               suite have a bedroom
# 399                                             -same-
#
# [400 rows x 9 columns]

# %%
# df_1 = merged_df[['Vervotech ID','room_type','ngrams','bed_count','bed_size','room_style','Vevotech Naming','hotelRoomType','no_of_people','Label','Remarks']]

# %%
df_1 = merged_df

# %%
df_1.tail(3)
# Out:
#      Vervotech ID        HotelBeds RoomName  \
# 397      38751099           1-Bedroom Suite
# 398      38751099           SUITE 1 BEDROOM
# 399      38751099  SUITE KING BED 1 BEDROOM
#
#                                                 ngrams  bed_count bed_size  \
# 397  [1, Bedroom, Suite, 1 Bedroom, Bedroom Suite, ...          1     King
# 398  [Suite, 1, Bedroom, Suite 1, 1 Bedroom, Suite ...          1     King
# 399  [Suite, King, Bed, 1, Bedroom, Suite King, Kin...          1     King
#
#     room_style  no_of_people Label                        Remarks
# 397      Suite           2.0     0  does the sweet have a bedroom
# 398      Suite           2.0     0           suite have a bedroom
# 399      Suite           2.0     0                         -same-

# %%
df1 = df_1.iloc[0:100]
df2 = df_1.iloc[100:200]
df3 = df_1.iloc[200:300]
df4 = df_1.iloc[300:400]

# %%
df1
# Out:
#     Vervotech ID                            HotelBeds RoomName  \
# 0       15780037       Premier Skyline View Room, 2 Queen Beds
# 1       15780037           Premier Skyline View Room, King Bed
# 2       15780037                          QUADRUPLE Accessible
# 3       15780037                             Room RUN OF HOUSE
# 4       15780037                                SUITE STANDARD
# ..           ...                                           ...
# 95      15614808  1 King Studio Mobility Access Roll In Shower
# 96      15614808                 SUITE Accessible-2 Queen Beds
# 97      15614808                SUITE Accessible KING SIZE BED
# 98      15253183                        DOUBLE DELUXE KING BED
# 99      15253183                         DOUBLE QUEEN SIZE BED
#
#                                                ngrams  bed_count bed_size  \
# 0   [Premier, Skyline, View, Room,, 2, Queen, Beds...          2    Queen
# 1   [Premier, Skyline, View, Room,, King, Bed, Pre...          1     King
# 2       [Quadruple, Accessible, Quadruple Accessible]          2     None
# 3   [Room, Run, Of, House, Room Run, Run Of, Of Ho...          1     None
# 4                   [Suite, Standard, Suite Standard]          1     King
# ..                                                ...        ...      ...
# 95  [1, King, Studio, Mobility, Access, Roll, In, ...          1     King
# 96  [Suite, Accessible, 2, Queen, Beds, Suite Acce...          2    Queen
# 97  [Suite, Accessible, King, Size, Bed, Suite Acc...          1     King
# 98  [Double, Deluxe, King, Bed, Double Deluxe, Del...          1     King
# 99  [Double, Queen, Size, Bed, Double Queen, Queen...          1    Queen
#
#    room_style  no_of_people Label  \
# 0     Premier           4.0  -1.0
# 1     Premier           2.0  -1.0
# 2   Quadruple           4.0  -1.0
# 3                       1.0   NaN
# 4       Suite           2.0   0.0
# ..        ...           ...   ...
# 95     Studio           2.0  -1.0
# 96      Suite           4.0   NaN
# 97      Suite           2.0  -1.0
# 98     Deluxe           2.0   NaN
# 99     Double           2.0   NaN
#
#                                               Remarks
# 0                2 queen bed can accommodate 4 people
# 1                           no. of people should be 2
# 2   Bed size cannot be single, if it accommadate f...
# 3                                                 NaN
# 4   suites normaly with king/queen/double/twon bed...
# ..                                                ...
# 95                          no. of people should be 2
# 96                                                NaN
# 97                          no. of people should be 2
# 98                                                NaN
# 99                                                NaN
#
# [100 rows x 9 columns]

# %%
df1.to_csv("Niranjani_test_set_Level_2.csv")
df2.to_csv("Nileka_test_set_Level_2.csv")
df3.to_csv("saumya_test_set_Level_2.csv")
df4.to_csv("Nuwan_test_set_Level_2.csv")
#df5.to_csv("YungChing_test_set_Level_2.csv")

# %% [markdown]
# ## Type A

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
style_size_dict = {
    'Deluxe': 'King',
    'Corner': 'Queen',
    'Standard': 'Single',
    'Suit': 'Twin Beds'
    
}

def extract_style_size(row):
    room_type = row['hotelRoomType']
    room_style = row['room_style']
    bed_size = row['bed_size']
    
    if not room_style and not bed_size:
        for token in nlp(room_type):
            if token.text in style_size_dict:
                bed_size = style_size_dict[token.text]
                room_style = token.text
                break
    
    elif not room_style:
        for token in nlp(room_type):
            if token.text in style_size_dict:
                room_style = token.text
                break
                
    elif not bed_size:
        if room_style in style_size_dict:
            bed_size = style_size_dict[room_style]
    
    row['room_style'] = room_style
    row['bed_size'] = bed_size
    return row

df = df.apply(extract_style_size, axis=1)

# %%
df.head(20)
# Out:
#     Vervotech ID  SupplierHotelId SupplierName      GroupId  \
# 0       15111741           782331    HotelBeds   15111741-1
# 1       15111788           782334    HotelBeds   15111788-1
# 2       15131097           782325    HotelBeds   15131097-1
# 3       15294880           766775    HotelBeds   15294880-1
# 4       15294880           766775    HotelBeds   15294880-2
# 5       15324900           141230    HotelBeds   15324900-1
# 6       15324900           141230    HotelBeds   15324900-1
# 7       15324900           141230    HotelBeds   15324900-2
# 8       15324900           141230    HotelBeds   15324900-3
# 9       15324900           141230    HotelBeds   15324900-4
# 10      15324900           141230    HotelBeds   15324900-5
# 11      15324900           141230    HotelBeds   15324900-6
# 12      15324900           141230    HotelBeds   15324900-7
# 13      15324900           141230    HotelBeds   15324900-7
# 14      15324900           141230    HotelBeds   15324900-7
# 15      15324900           141230    HotelBeds   15324900-8
# 16      15324900           141230    HotelBeds   15324900-8
# 17      15324900           141230    HotelBeds   15324900-9
# 18      15324900           141230    HotelBeds  15324900-10
# 19      15324900           141230    HotelBeds  15324900-11
#
#    HotelBeds RoomCode                      HotelBeds RoomName  \
# 0           APT.KG-PE              APARTMENT PREMIER KING BED
# 1              APT.2K                   APARTMENT 2 KING BEDS
# 2              APT.KG                 APARTMENT KING SIZE BED
# 3              DBL.QN                   DOUBLE QUEEN SIZE BED
# 4            SUI.KG-1                     SUITE KING SIZE BED
# 5           DBL.2Q-DX            2 Queen Beds Deluxe Nonsmoke
# 6           ROO.2Q-DX            2 QUEEN BEDS DELUXE NONSMOKE
# 7           DBL.DX-KG  King Deluxe Accessible Roll Shwr Nosmk
# 8              DBL.KG                   KING LEISURE NONSMOKE
# 9           DBL.H6-KG         DOUBLE Accessible KING SIZE BED
# 10          DBL.CV-KG               DOUBLE CITY VIEW KING BED
# 11          QUA.2Q-NM      QUADRUPLE 2 QUEEN BEDS NON SMOKING
# 12          DBL.NM-QN                  1 QUEEN BED NONSMOKING
# 13          ROO.NM-QN              Room QUEEN BED NON SMOKING
# 14             DBL.QN                   DOUBLE QUEEN SIZE BED
# 15             DBT.2Q             Double or Twin 2 QUEEN BEDS
# 16             DBL.2Q                     DOUBLE 2 QUEEN BEDS
# 17          DBL.H6-2Q          DOUBLE Accessible-2 Queen Beds
# 18             ROO.RO                       Room RUN OF HOUSE
# 19           DBL.ST-2                         DOUBLE STANDARD
#
#    Vervotech MappedStandardName                               room_type  \
# 0             Apartment Premier              Apartment Premier King Bed
# 1                     Apartment                 Apartment  2  King Beds
# 2                     Apartment                 Apartment King Size Bed
# 3                    Queen Room                          Queen Size Bed
# 4                         Suite                     Suite King Size Bed
# 5               Deluxe, 2 Queen           2  Queen Beds Deluxe Nonsmoke
# 6               Deluxe, 2 Queen           2  Queen Beds Deluxe Nonsmoke
# 7      Deluxe, King, Accessible  King Deluxe Accessible Roll Shwr Nosmk
# 8                     King Room                   King Leisure Nonsmoke
# 9         King Room, Accessible                Accessible King Size Bed
# 10         King Room, City View                      City View King Bed
# 11               Quadruple Room    Quadruple  2  Queen Beds Non Smoking
# 12                   Queen Room                 1  Queen Bed Nonsmoking
# 13                   Queen Room              Room Queen Bed Non Smoking
# 14                   Queen Room                          Queen Size Bed
# 15               Room - 2 Queen                  Or Twin  2  Queen Beds
# 16               Room - 2 Queen                           2  Queen Beds
# 17   Room - 2 Queen, Accessible               Accessible  2  Queen Beds
# 18                 Run Of House                       Room Run Of House
# 19                Standard Room                                Standard
#
#                                                ngrams  bed_count bed_size  \
# 0   [Apartment, Premier, King, Bed, Apartment Prem...          1     King
# 1   [Apartment, 2, King, Beds, Apartment 2, 2 King...          2     King
# 2   [Apartment, King, Size, Bed, Apartment King, K...          1     King
# 3   [Double, Queen, Size, Bed, Double Queen, Queen...          2    Queen
# 4   [Suite, King, Size, Bed, Suite King, King Size...          1     King
# 5   [2, Queen, Beds, Deluxe, Nonsmoke, 2 Queen, Qu...          2    Queen
# 6   [2, Queen, Beds, Deluxe, Nonsmoke, 2 Queen, Qu...          2    Queen
# 7   [King, Deluxe, Accessible, Roll, Shwr, Nosmk, ...          1     King
# 8   [King, Leisure, Nonsmoke, King Leisure, Leisur...          1     King
# 9   [Double, Accessible, King, Size, Bed, Double A...          2     King
# 10  [Double, City, View, King, Bed, Double City, C...          2     King
# 11  [Quadruple, 2, Queen, Beds, Non, Smoking, Quad...          2    Queen
# 12  [1, Queen, Bed, Nonsmoking, 1 Queen, Queen Bed...          1    Queen
# 13  [Room, Queen, Bed, Non, Smoking, Room Queen, Q...          1    Queen
# 14  [Double, Queen, Size, Bed, Double Queen, Queen...          2    Queen
# 15  [Double, Or, Twin, 2, Queen, Beds, Double Or, ...          2     Twin
# 16  [Double, 2, Queen, Beds, Double 2, 2 Queen, Qu...          2    Queen
# 17  [Double, Accessible, 2, Queen, Beds, Double Ac...          2    Queen
# 18  [Room, Run, Of, House, Room Run, Run Of, Of Ho...          1
# 19                [Double, Standard, Double Standard]          2
#
#     room_style             Vevotech Naming  \
# 0    Apartment           Apartment Premier
# 1    Apartment                   Apartment
# 2    Apartment                   Apartment
# 3                               Queen Room
# 4        Suite                       Suite
# 5       Deluxe             Deluxe, 2 Queen
# 6       Deluxe             Deluxe, 2 Queen
# 7       Deluxe    Deluxe, King, Accessible
# 8      Leisure                   King Room
# 9   Accessible       King Room, Accessible
# 10                    King Room, City View
# 11                          Quadruple Room
# 12                              Queen Room
# 13                              Queen Room
# 14                              Queen Room
# 15                          Room - 2 Queen
# 16                          Room - 2 Queen
# 17  Accessible  Room - 2 Queen, Accessible
# 18                            Run Of House
# 19    Standard               Standard Room
#
#                              hotelRoomType
# 0               Apartment Premier King Bed
# 1                  Apartment  2  King Beds
# 2                  Apartment King Size Bed
# 3                           Queen Size Bed
# 4                      Suite King Size Bed
# 5            2  Queen Beds Deluxe Nonsmoke
# 6            2  Queen Beds Deluxe Nonsmoke
# 7   King Deluxe Accessible Roll Shwr Nosmk
# 8                    King Leisure Nonsmoke
# 9                 Accessible King Size Bed
# 10                      City View King Bed
# 11    Quadruple  2  Queen Beds Non Smoking
# 12                 1  Queen Bed Nonsmoking
# 13              Room Queen Bed Non Smoking
# 14                          Queen Size Bed
# 15                  Or Twin  2  Queen Beds
# 16                           2  Queen Beds
# 17               Accessible  2  Queen Beds
# 18                       Room Run Of House
# 19                                Standard

# %% [markdown]
# ## Type B

# %%
room_bed_dict = {
    "Standard": "King",
    "Deluxe": "Queen",
    "Suite": "King",
    "Executive": "King"
    
    # add more pairs
}

# %%
for i, row in df.iterrows():
    if row['bed_size'] == '':
        room_style = row['room_style']
        if room_style in room_bed_dict:
            bed_size = room_bed_dict[room_style]
            df.at[i, 'bed_size'] = bed_size

# %%
df.to_csv("test_3.csv")
